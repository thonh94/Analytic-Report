# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
#    Currently, more and more Bom hit movies are being shown around the world. Each movie will depend on the genre, the target age, the gender, and the message of each movie that it will attract different audiences in different regions. In addition, those factors directly affect the sales of each movie.
#
# At the same time, choosing the timing of the film's release sometimes affects the sales of all filmmakers nowadays. A typical example can be mentioned that the Covid-19 pandemic disaster greatly affected the sales of the movies being shown during that period.
#
# For the following analysis, we rely on a data sheet of factors surveyed from movies around the world, to focus on solving three key issues that are considered the most influential to the revenue of the movies:
#
# ## 1.	What areas have the most influence on revenue?
# ## 2.	How is a movie’s revenue and average score affected by its genre?
# ## 3.	What influence does release date have on revenue?

# %% [markdown]
# # We have metadata on ~ 5,000 movies from TMDb as below:

# %%
import pandas as pd

# %%
moviedata = pd.read_csv('Downloads/tmdb_5000_movies.csv')

# %%
moviedata.shape
# Out:
# (4803, 20)

# %%
moviedata.head(4803)
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# The above data shows us in detail the elements of a movie, some of which, when it changes, have the potential to have a direct effect on the movie's revenue. If we analyze and evaluate these factors accurately, we can base on that to come up with appropriate strategies and plans to help increase the revenue significantly for filmmakers around the world. Some typical factors are as follows: genres; languages; production company; production countries; release date; revenue; vote average ...

# %% [markdown]
# ## For solving the first question "What areas have the most influence on revenue?"
# We'll only need to focus on two column of the above moviedata. That're "Product-countries" & "Revenue"

# %%
q1data = pd.read_csv('Downloads/q1_tmdb_5000_movies.csv')

# %%
q1data.head(4803)
# Out:
#                                    production_countries     revenue
# 0     [{"iso_3166_1": "US", "name": "United States o...  2787965087
# 1     [{"iso_3166_1": "US", "name": "United States o...   961000000
# 2     [{"iso_3166_1": "GB", "name": "United Kingdom"...   880674609
# 3     [{"iso_3166_1": "US", "name": "United States o...  1084939099
# 4     [{"iso_3166_1": "US", "name": "United States o...   284139100
# ...                                                 ...         ...
# 4798  [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...     2040920
# 4799                                                 []           0
# 4800  [{"iso_3166_1": "US", "name": "United States o...           0
# 4801  [{"iso_3166_1": "US", "name": "United States o...           0
# 4802  [{"iso_3166_1": "US", "name": "United States o...           0
#
# [4803 rows x 2 columns]

# %% [markdown]
# # For solving the second question "How is a movie’s revenue and average score affected by its genre?"
# We'll only need to focus on three column of the above moviedata. That're "genres" & "Revenue" & "vote average"

# %%
q2data = pd.read_csv('Downloads/q2_tmdb_5000_movies.csv')

# %%
q2data.head(4803)
# Out:
#                                                  genres     revenue  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...  2787965087
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...   961000000
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...   880674609
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...  1084939099
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...   284139100
# ...                                                 ...         ...
# 4798  [{"id": 28, "name": "Action"}, {"id": 80, "nam...     2040920
# 4799  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...           0
# 4800  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...           0
# 4801                                                 []           0
# 4802                [{"id": 99, "name": "Documentary"}]           0
#
#       vote_average
# 0              7.2
# 1              6.9
# 2              6.3
# 3              7.6
# 4              6.1
# ...            ...
# ...

# %% [markdown]
# # For solving the second question "What influence does release date have on revenue?"
# We'll only need to focus on two column of the above moviedata. That're "Revenue" & "release date"

# %%
q3data = pd.read_csv('Downloads/q2_tmdb_5000_movies.csv')

# %%
q3data.head(4803)
# Out:
#                                                  genres     revenue  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...  2787965087
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...   961000000
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...   880674609
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...  1084939099
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...   284139100
# ...                                                 ...         ...
# 4798  [{"id": 28, "name": "Action"}, {"id": 80, "nam...     2040920
# 4799  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...           0
# 4800  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...           0
# 4801                                                 []           0
# 4802                [{"id": 99, "name": "Documentary"}]           0
#
#       vote_average
# 0              7.2
# 1              6.9
# 2              6.3
# 3              7.6
# 4              6.1
# ...            ...
# ...
